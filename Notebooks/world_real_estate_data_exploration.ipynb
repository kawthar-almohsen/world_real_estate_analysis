# %%
import pandas as pd

# %%
realestate_df = pd.read_csv('world_real_estate_data.csv')

# %%
realestate_df
# Out:
#                                                     title   country  \
# 0       2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1                   4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2               1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3                  1 room apartment  in Pattaya, Thailand  Thailand
# 4                  2 room apartment  in Pattaya, Thailand  Thailand
# ...                                                   ...       ...
# 147531        5 room apartment 310 m² in Gazipasa, Turkey    Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey    Turkey
# 147533        2 room apartment  in Marmara Region, Turkey    Turkey
# 147534                       Apartment  in Akarca, Turkey    Turkey
# 147535                 4 room apartment 140 m² in, Turkey    Turkey
#
#                                          location  building_construction_year  \
# ...

# %%
realestate_df.describe
# Out:
# <bound method NDFrame.describe of                                                     title   country  \
# 0       2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1                   4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2               1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3                  1 room apartment  in Pattaya, Thailand  Thailand
# 4                  2 room apartment  in Pattaya, Thailand  Thailand
# ...                                                   ...       ...
# 147531        5 room apartment 310 m² in Gazipasa, Turkey    Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey    Turkey
# 147533        2 room apartment  in Marmara Region, Turkey    Turkey
# 147534                       Apartment  in Akarca, Turkey    Turkey
# 147535                 4 room apartment 140 m² in, Turkey    Turkey
#
#                                          location  building_construction_year  \
# ...

# %%
realestate_df.sample(5)
# Out:
#                                                    title   country  \
# 115155        5 room apartment 128 m² in Zagreb, Croatia   Croatia
# 133491        Condo 2 bedrooms 70 m² in Phuket, Thailand  Thailand
# 125313  3 room house  in Municipality of Thassos, Greece    Greece
# 126124      Townhouse 2 bedrooms 85 m² in Nikiti, Greece    Greece
# 44526        5 room house 150 m² in Nagykovacsi, Hungary   Hungary
#
#                                                  location  \
# 115155                                    Zagreb, Croatia
# 133491                  Phuket Province, Phuket, Thailand
# 125313  Macedonia and Thrace, Municipality of Thassos,...
# 126124  Nikiti, Macedonia and Thrace, The Municipality...
# 44526   Nagykovacsi, Central Hungary, Budakeszi jaras,...
#
#         building_construction_year  building_total_floors  apartment_floor  \
# 115155                         NaN                    NaN              NaN
# ...

# %%
realestate_df.head()
# Out:
#                                                title   country  \
# 0  2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1              4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2          1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3             1 room apartment  in Pattaya, Thailand  Thailand
# 4             2 room apartment  in Pattaya, Thailand  Thailand
#
#                                     location  building_construction_year  \
# 0               Mediterranean Region, Turkey                         NaN
# 1  Kalkan, Mediterranean Region, Kas, Turkey                      2021.0
# 2      Mediterranean Region, Antalya, Turkey                         NaN
# 3      Chon Buri Province, Pattaya, Thailand                      2020.0
# 4      Chon Buri Province, Pattaya, Thailand                      2026.0
#
#    building_total_floors  apartment_floor  apartment_rooms  \
# 0                    5.0              1.0              3.0
# ...

# %%
realestate_df.tail()
# Out:
#                                                     title country  \
# 147531        5 room apartment 310 m² in Gazipasa, Turkey  Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey  Turkey
# 147533        2 room apartment  in Marmara Region, Turkey  Turkey
# 147534                       Apartment  in Akarca, Turkey  Turkey
# 147535                 4 room apartment 140 m² in, Turkey  Turkey
#
#                                        location  building_construction_year  \
# 147531   Mediterranean Region, Gazipasa, Turkey                         NaN
# 147532                   Marmara Region, Turkey                      2023.0
# 147533                   Marmara Region, Turkey                         NaN
# 147534  Akarca, Central Anatolia Region, Turkey                      2023.0
# 147535                                   Turkey                         NaN
#
#         building_total_floors  apartment_floor  apartment_rooms  \
# ...

# %%
realestate_df.shape
# Out:
# (147536, 14)

# %%
realestate_df.dtypes
# Out:
# title                          object
# country                        object
# location                       object
# building_construction_year    float64
# building_total_floors         float64
# apartment_floor               float64
# apartment_rooms               float64
# apartment_bedrooms            float64
# apartment_bathrooms           float64
# apartment_total_area           object
# apartment_living_area          object
# price_in_USD                  float64
# image                          object
# url                            object
# dtype: object

# %%
realestate_df.size
# Out:
# 2065504

# %%
realestate_df.info
# Out:
# <bound method DataFrame.info of                                                     title   country  \
# 0       2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1                   4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2               1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3                  1 room apartment  in Pattaya, Thailand  Thailand
# 4                  2 room apartment  in Pattaya, Thailand  Thailand
# ...                                                   ...       ...
# 147531        5 room apartment 310 m² in Gazipasa, Turkey    Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey    Turkey
# 147533        2 room apartment  in Marmara Region, Turkey    Turkey
# 147534                       Apartment  in Akarca, Turkey    Turkey
# 147535                 4 room apartment 140 m² in, Turkey    Turkey
#
#                                          location  building_construction_year  \
# ...

# %%
realestate_df.columns
# Out:
# Index(['title', 'country', 'location', 'building_construction_year',
#        'building_total_floors', 'apartment_floor', 'apartment_rooms',
#        'apartment_bedrooms', 'apartment_bathrooms', 'apartment_total_area',
#        'apartment_living_area', 'price_in_USD', 'image', 'url'],
#       dtype='object')

# %%
realestate_df.isnull()
# Out:
#         title  country  location  building_construction_year  \
# 0       False    False     False                        True
# 1       False    False     False                       False
# 2       False    False     False                        True
# 3       False    False     False                       False
# 4       False    False     False                       False
# ...       ...      ...       ...                         ...
# 147531  False    False     False                        True
# 147532  False    False     False                       False
# 147533  False    False     False                        True
# 147534  False    False     False                       False
# 147535  False    False     False                        True
#
#         building_total_floors  apartment_floor  apartment_rooms  \
# 0                       False            False            False
# 1                       False             True             True
# ...

# %%
realestate_df.isnull().sum()
# Out:
# title                              0
# country                          130
# location                         131
# building_construction_year     82817
# building_total_floors          79312
# apartment_floor                92944
# apartment_rooms                73358
# apartment_bedrooms            110554
# apartment_bathrooms            91563
# apartment_total_area            5740
# apartment_living_area         119824
# price_in_USD                    2575
# image                              0
# url                                0
# dtype: int64

# %%
realestate_df.isnull().sum().sum()
# Out:
# 658948
